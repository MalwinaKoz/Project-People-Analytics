# %% [markdown]
# # Raw data
# Our data consists of answers given by the student bodice that joined newly found organization WAIT. IT's an university organization which main goal is to create friendly environment for its members. It mainly focuses on technical skills and some specific soft skills.
#
# Our rwa data have 67 records with various answers about skills graded from 1 to 5 and type of sudents engagement. Of course while answering all of the questions our data bank grows with "garbage" data like:
#  - modification time
#  - start time
#  - end time
#  - email adress which was set to anonymous by default
#  - and a name.

# %%
import pandas as pd

# %%
file_path = '../data/01_Raw/01_DataCompetencySurvey.xlsx'
raw_data = pd.read_excel(file_path)
raw_data
# Out:
#     ID Godzina rozpoczęcia  Godzina ukończenia Adres e-mail  Nazwa  \
# 0    1 2024-03-05 15:25:52 2024-03-05 15:33:04    anonymous    NaN
# 1    2 2024-03-05 15:29:46 2024-03-05 15:35:02    anonymous    NaN
# 2    3 2024-03-05 15:16:30 2024-03-05 15:37:17    anonymous    NaN
# 3    4 2024-03-05 15:34:17 2024-03-05 15:38:01    anonymous    NaN
# 4    5 2024-03-05 15:34:26 2024-03-05 15:38:20    anonymous    NaN
# ..  ..                 ...                 ...          ...    ...
# 62  63 2024-04-03 15:24:10 2024-04-03 15:33:56    anonymous    NaN
# 63  64 2024-04-03 19:14:10 2024-04-03 19:18:22    anonymous    NaN
# 64  65 2024-04-08 10:31:25 2024-04-08 10:32:10    anonymous    NaN
# 65  66 2024-04-08 21:45:20 2024-04-08 21:46:43    anonymous    NaN
# 66  67 2024-04-14 18:29:20 2024-04-14 18:33:23    anonymous    NaN
#
#     Czas ostatniej modyfikacji  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# ...

# %%
preprocessed_data = raw_data.drop(['Godzina rozpoczęcia','Godzina ukończenia','Adres e-mail','Nazwa','Czas ostatniej modyfikacji',
                                   'Masz jakiś pomysł na projekt data? Napisz nam o tym. Jeżeli to nie ten moment, pozostaw puste pole.',],axis=1)
preprocessed_data.to_csv('..//data//02_Interim//01_SelectedFeutures.csv', index=False)
